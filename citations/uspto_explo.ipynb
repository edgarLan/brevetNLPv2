# %% [markdown]
# ## patent parser

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\edgar\OneDrive\Bureau\Ecole\HEC\A24\BrevetNLP\PatentNovelty\citations

# %%
from uspto import *

# %%
from uspto import uspto

# %%
file_list = uspto.get_patent_files_by_year(2008)

# %%
file_list
# Out:
# ['ipg080101.zip',
#  'ipg080108.zip',
#  'ipg080115.zip',
#  'ipg080122.zip',
#  'ipg080129.zip',
#  'ipg080205.zip',
#  'ipg080212.zip',
#  'ipg080219.zip',
#  'ipg080226.zip',
#  'ipg080304.zip',
#  'ipg080311.zip',
#  'ipg080318.zip',
#  'ipg080325.zip',
#  'ipg080401.zip',
#  'ipg080408.zip',
#  'ipg080415.zip',
#  'ipg080422.zip',
#  'ipg080429.zip',
#  'ipg080506.zip',
#  'ipg080513.zip',
#  'ipg080520.zip',
#  'ipg080527.zip',
#  'ipg080603.zip',
#  'ipg080610.zip',
#  'ipg080617.zip',
#  'ipg080624.zip',
#  'ipg080701.zip',
#  'ipg080708.zip',
#  'ipg080715.zip',
#  'ipg080722.zip',
#  'ipg080729.zip',
#  'ipg080805.zip',
#  'ipg080812.zip',
#  'ipg080819.zip',
#  'ipg080826.zip',
#  'ipg080902.zip',
#  'ipg080909.zip',
#  'ipg080916.zip',
#  'ipg080923.zip',
#  'ipg080930.zip',
#  'ipg081007.zip',
#  'ipg081014.zip',
#  'ipg081021.zip',
#  'ipg081028.zip',
#  'ipg081104.zip',
#  'ipg081111.zip',
#  'ipg081118.zip',
#  'ipg081125.zip',
#  'ipg081202.zip',
#  'ipg081209.zip',
# ...

# %%
file_path = "C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data"
url = 'https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/1999/pftaps19990406_wk14.zip'
uspto.download_file_to_disk(url, file_path)

# %%
# data = uspto.download_yearly_data(1980,)
url = 'https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/1980/pftaps19801230_wk53.zip'
items = ['UREF']
data = uspto.read_and_parse_from_url(url,items)

# %%
data
# Out:
# [{'bibliographic_information': {'Patent Number': 'D02576961',
#    'Series Code': '5',
#    'Application Number': '9399062',
#    'Application Type': '4',
#    'Art unit': '292',
#    'Application Filing Date': '19780905',
#    'Title of Invention': 'Jacket',
#    'Issue Date': '19801230',
#    'Number of Claims': '1',
#    'Exemplary Claim Number(s)': '1',
#    'Assistant Examiner': 'Corrigan; Jane E.',
#    'Primary Examiner': 'Stearman; Joel',
#    'Number of Drawing Sheets': '2',
#    'Number of figures': '3',
#    'Term of Patent': '14'},
#   'citations': [{'Patent number': 'D128065',
#     'Issue date': '19410700',
#     'Patentee name': 'Fromm',
#     'US classification': 'D 2182'},
#    {'Patent number': '2124366',
#     'Issue date': '19380700',
#     'Patentee name': 'De Lasarte',
#     'US classification': 'D 2 79'}]},
#  {'bibliographic_information': {'Patent Number': 'D02576970',
#    'Series Code': '5',
#    'Application Number': '8599831',
# ...
