# %% [markdown]
# # Réseau citations

# %%
import zipfile
import pandas as pd

# %%
filename = "/home/edgarlanoue/citationsData/comp/g_us_patent_citation.tsv.zip" #"C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/comp/g_us_patent_citation.tsv.zip"
output_file = "/home/edgarlanoue/citationsData/data/g_us_patent_citation_full.tsv" #"C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/data/g_us_patent_citation_full.tsv"

filename = "C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/comp/g_us_patent_citation.tsv.zip"
output_file = "C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/data/g_us_patent_citation_full.tsv"

# %%
    # Open the ZIP file and read the TSV file directly
with zipfile.ZipFile(filename, 'r') as zip_ref:
    # List files in the zip to find the TSV file
    for file_info in zip_ref.infolist():
        if file_info.filename.endswith('.tsv'):
            # Read the TSV file into a DataFrame
            with zip_ref.open(file_info.filename) as tsv_file:
                df = pd.read_csv(tsv_file, sep='\t', on_bad_lines='skip')

                # Select the first 1000 rows
                # df_first_1000 = df.head(1000000)

                # Export the selected rows to a new TSV file
                df.to_csv(output_file, sep='\t', index=False)
                print(f"Exported  to {output_file}")
# Out:
# Exported the first 1000 rows to /home/edgarlanoue/citationsData/data/g_us_patent_citation_full.tsv

# %%
# Open the ZIP file and read the TSV file directly
with zipfile.ZipFile(filename, 'r') as zip_ref:
    # List files in the zip to find the TSV file
    for file_info in zip_ref.infolist():
        if file_info.filename.endswith('.tsv'):
            # Read the TSV file in chunks to manage memory usage
            with zip_ref.open(file_info.filename) as tsv_file:
                # Initialize chunk size (adjust based on memory availability)
                chunk_size = 100000  # Number of rows per chunk
                total_rows = 0  # Initialize row counter

                # Use a flag to control header writing
                header_written = False

                # Read the file in chunks and export to TSV
                for chunk in pd.read_csv(tsv_file, sep='\t', on_bad_lines='skip', chunksize=chunk_size):
                    # Append each chunk to the output file
                    chunk.to_csv(output_file, sep='\t', mode='a', header=not header_written, index=False)
                    header_written = True  # After the first write, header should not be written again
                    
                    # Update the total row count
                    total_rows += len(chunk)

                    # Optional: print progress every certain number of rows
                    if total_rows % 1000000 == 0:  # Adjust based on preference
                        print(f"Processed {total_rows} rows so far.")

                print(f"Exported {total_rows} rows to {output_file}.")
# Out:
# Processed 1000000 rows so far.
# Processed 2000000 rows so far.
# Processed 3000000 rows so far.
# Processed 4000000 rows so far.
# Processed 5000000 rows so far.
# Processed 6000000 rows so far.
# Processed 7000000 rows so far.
# Processed 8000000 rows so far.
# Processed 9000000 rows so far.
# Processed 10000000 rows so far.
# Processed 11000000 rows so far.
# Processed 12000000 rows so far.
# Processed 13000000 rows so far.
# Processed 14000000 rows so far.
# Processed 15000000 rows so far.
# Processed 16000000 rows so far.
# Processed 17000000 rows so far.
# Processed 18000000 rows so far.
# Processed 19000000 rows so far.
# Processed 20000000 rows so far.
# Processed 21000000 rows so far.
# Processed 22000000 rows so far.
# Processed 23000000 rows so far.
# Processed 24000000 rows so far.
# Processed 25000000 rows so far.
# Processed 26000000 rows so far.
# Processed 27000000 rows so far.
# Processed 28000000 rows so far.
# Processed 29000000 rows so far.
# ...

# %%
# Initialize row count
total_rows = 0
print_frequency = 1000000

with zipfile.ZipFile(filename, 'r') as zip_ref:
    # Iterate through the files in the ZIP
    for file_info in zip_ref.infolist():
        if file_info.filename.endswith('.tsv'):
            # Open the TSV file
            with zip_ref.open(file_info.filename) as tsv_file:
                # Count the total number of rows
                for line in tsv_file:
                    total_rows += 1  # Increment row count for each line
                    # Print updated total_rows
                    if total_rows % print_frequency == 0:
                        print(f"Total rows so far in {file_info.filename}: {total_rows}")


            print(f"Final total rows in {file_info.filename}: {total_rows}")
# Out:
# Total rows so far in g_us_patent_citation.tsv: 1000000
# Total rows so far in g_us_patent_citation.tsv: 2000000
# Total rows so far in g_us_patent_citation.tsv: 3000000
# Total rows so far in g_us_patent_citation.tsv: 4000000
# Total rows so far in g_us_patent_citation.tsv: 5000000
# Total rows so far in g_us_patent_citation.tsv: 6000000
# Total rows so far in g_us_patent_citation.tsv: 7000000
# Total rows so far in g_us_patent_citation.tsv: 8000000
# Total rows so far in g_us_patent_citation.tsv: 9000000
# Total rows so far in g_us_patent_citation.tsv: 10000000
# Total rows so far in g_us_patent_citation.tsv: 11000000
# Total rows so far in g_us_patent_citation.tsv: 12000000
# Total rows so far in g_us_patent_citation.tsv: 13000000
# Total rows so far in g_us_patent_citation.tsv: 14000000
# Total rows so far in g_us_patent_citation.tsv: 15000000
# Total rows so far in g_us_patent_citation.tsv: 16000000
# Total rows so far in g_us_patent_citation.tsv: 17000000
# ...

# %%
# Path to your exported TSV file
output_file = "/home/edgarlanoue/citationsData/data/g_us_patent_citation_full.tsv"

# Load the TSV file into a DataFrame
df = pd.read_csv(output_file, nrows=150000000, sep='\t', on_bad_lines='skip')

# Display the first few rows of the DataFrame
print(df.head())

# %%
filename = "C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/comp/g_us_application_citation.tsv.zip"
output_file = "C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/data/g_us_application_citation.tsv"

# Open the ZIP file and read the TSV file directly
with zipfile.ZipFile(filename, 'r') as zip_ref:
    # List files in the zip to find the TSV file
    for file_info in zip_ref.infolist():
        if file_info.filename.endswith('.tsv'):
            # Read the TSV file into a DataFrame
            with zip_ref.open(file_info.filename) as tsv_file:
                df = pd.read_csv(tsv_file, sep='\t', nrows=1000, engine='python', on_bad_lines='skip')

                # Select the first 1000 rows
                df_first_1000 = df.head(1000)

                # Export the selected rows to a new TSV file
                df_first_1000.to_csv(output_file, sep='\t', index=False)
                print(f"Exported the first 1000 rows to {output_file}")
# Out:
# Exported the first 1000 rows to C:/Users/edgar/OneDrive/Bureau/Ecole/HEC/A24/BrevetNLP/citations_data/data/g_us_application_citation.tsv
